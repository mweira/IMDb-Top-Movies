# %%
import pandas as pd

# %%
df = pd.read_csv('imdb_top_movies_1980_2026.csv')

# %%
df.query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#      imdb_id                     title            original_title  year  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  1994
# 1  tt0468569           The Dark Knight           The Dark Knight  2008
# 2  tt1375666                 Inception                 Inception  2010
# 3  tt0137523                Fight Club                Fight Club  1999
# 4  tt0816692              Interstellar              Interstellar  2014
#
#    runtime_minutes                   genres  average_rating  num_votes  \
# 0            142.0                    Drama             9.3    3182733
# 1            152.0       Action,Crime,Drama             9.1    3161984
# 2            148.0  Action,Adventure,Sci-Fi             8.8    2811692
# 3            139.0     Crime,Drama,Thriller             8.8    2601984
# 4            169.0   Adventure,Drama,Sci-Fi             8.7    2521607
#
#                                imdb_url
# 0  https://www.imdb.com/title/tt0111161
# ...

# %%
df.columns
# Out:
# Index(['imdb_id', 'title', 'original_title', 'year', 'runtime_minutes',
#        'genres', 'average_rating', 'num_votes', 'imdb_url'],
#       dtype='object')

# %%
df.tail(3)
# Out:
#           imdb_id             title  original_title  year  runtime_minutes  \
# 16249  tt10994688         The Binge       The Binge  2020             98.0
# 16250   tt0263743       Billionaire       Milyarder  1987             96.0
# 16251   tt1921078  Saint Petersburg  San Peterzburg  2010            120.0
#
#                    genres  average_rating  num_votes  \
# 16249              Comedy             5.3       5000
# 16250        Comedy,Drama             7.5       5000
# 16251  Comedy,Crime,Drama             6.4       5000
#
#                                     imdb_url
# 16249  https://www.imdb.com/title/tt10994688
# 16250   https://www.imdb.com/title/tt0263743
# 16251   https://www.imdb.com/title/tt1921078

# %%
df.shape
# Out:
# (16252, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16252 entries, 0 to 16251
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   imdb_id          16252 non-null  object
#  1   title            16252 non-null  object
#  2   original_title   16252 non-null  object
#  3   year             16252 non-null  int64
#  4   runtime_minutes  16251 non-null  float64
#  5   genres           16246 non-null  object
#  6   average_rating   16252 non-null  float64
#  7   num_votes        16252 non-null  int64
#  8   imdb_url         16252 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
df['year']
# Out:
# 0        1994
# 1        2008
# 2        2010
# 3        1999
# 4        2014
#          ...
# 16247    2016
# 16248    1991
# 16249    2020
# 16250    1987
# 16251    2010
# Name: year, Length: 16252, dtype: int64

# %%
df['year'].head()
# Out:
# 0    1994
# 1    2008
# 2    2010
# 3    1999
# 4    2014
# Name: year, dtype: int64

# %%
df[['title', 'year', 'runtime_minutes', 'average_rating', 'num_votes']].head()
# Out:
#                       title  year  runtime_minutes  average_rating  num_votes
# 0  The Shawshank Redemption  1994            142.0             9.3    3182733
# 1           The Dark Knight  2008            152.0             9.1    3161984
# 2                 Inception  2010            148.0             8.8    2811692
# 3                Fight Club  1999            139.0             8.8    2601984
# 4              Interstellar  2014            169.0             8.7    2521607

# %%
# .loc sempre faz slicing INCLUSIVO, ou seja, inclui o elemento do índice final inserido

df.loc[1:4, ['title', 'year']]
# Out:
#              title  year
# 1  The Dark Knight  2008
# 2        Inception  2010
# 3       Fight Club  1999
# 4     Interstellar  2014

# %%
df.iloc[1:4, 1:4]
# Out:
#              title   original_title  year
# 1  The Dark Knight  The Dark Knight  2008
# 2        Inception        Inception  2010
# 3       Fight Club       Fight Club  1999

# %%
df['year'] > 2003
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 16247     True
# 16248    False
# 16249     True
# 16250    False
# 16251     True
# Name: year, Length: 16252, dtype: bool

# %%
df.loc[df['year'] > 2003]
# Out:
#           imdb_id                  title         original_title  year  \
# 1       tt0468569        The Dark Knight        The Dark Knight  2008
# 2       tt1375666              Inception              Inception  2010
# 4       tt0816692           Interstellar           Interstellar  2014
# 11      tt1345836  The Dark Knight Rises  The Dark Knight Rises  2012
# 13      tt1853728       Django Unchained       Django Unchained  2012
# ...           ...                    ...                    ...   ...
# 16244  tt19864832              La Cocina              La cocina  2024
# 16245   tt4992086  Bhale Bhale Magadivoy  Bhale Bhale Magadivoy  2015
# 16247   tt3544218                Belgica                Belgica  2016
# 16249  tt10994688              The Binge              The Binge  2020
# 16251   tt1921078       Saint Petersburg         San Peterzburg  2010
#
#        runtime_minutes                   genres  average_rating  num_votes  \
# ...

# %%
df.loc[df['year'] > 2003].shape
# Out:
# (11485, 9)

# %%
df.loc[(df['year'] > 2020) & (df['average_rating'] > 8.0)]
# Out:
#           imdb_id                                         title  \
# 75     tt15398776                                   Oppenheimer
# 76     tt10872600                       Spider-Man: No Way Home
# 127     tt1745960                             Top Gun: Maverick
# 180    tt15239678                                Dune: Part Two
# 273    tt10811166                             The Kashmir Files
# ...           ...                                           ...
# 15325  tt15964372                                     Aparajito
# 15463  tt16492636  Demon Slayer: Kimetsu no Yaiba - Asakusa Arc
# 15466  tt27302079                                        Aattam
# 15933  tt33022710                 Ocean with David Attenborough
# 15954  tt32292009                                        Laggam
#
#                       original_title  year  runtime_minutes  \
# 75                       Oppenheimer  2023            180.0
# 76           Spider-Man: No Way Home  2021            148.0
# ...

# %%
# Especificando as colunas que quero retornar 

df.loc[(df['year'] > 2020) & (df['average_rating'] > 8.0), ['title', 'year', 'average_rating']]
# Out:
#                                               title  year  average_rating
# 75                                      Oppenheimer  2023             8.2
# 76                          Spider-Man: No Way Home  2021             8.1
# 127                               Top Gun: Maverick  2022             8.2
# 180                                  Dune: Part Two  2024             8.4
# 273                               The Kashmir Files  2022             8.5
# ...                                             ...   ...             ...
# 15325                                     Aparajito  2022             8.7
# 15463  Demon Slayer: Kimetsu no Yaiba - Asakusa Arc  2021             8.5
# 15466                                        Aattam  2023             8.1
# 15933                 Ocean with David Attenborough  2025             8.5
# 15954                                        Laggam  2024             8.2
#
# [88 rows x 3 columns]

# %%
df.loc[(df['year'] < 2000) | (df['average_rating'] < 8.0)]
# Out:
#           imdb_id                     title            original_title  year  \
# 0       tt0111161  The Shawshank Redemption  The Shawshank Redemption  1994
# 3       tt0137523                Fight Club                Fight Club  1999
# 5       tt0109830              Forrest Gump              Forrest Gump  1994
# 6       tt0110912              Pulp Fiction              Pulp Fiction  1994
# 7       tt0133093                The Matrix                The Matrix  1999
# ...           ...                       ...                       ...   ...
# 16247   tt3544218                   Belgica                   Belgica  2016
# 16248   tt0101733    Dil Hai Ki Manta Nahin    Dil Hai Ki Manta Nahin  1991
# 16249  tt10994688                 The Binge                 The Binge  2020
# 16250   tt0263743               Billionaire                 Milyarder  1987
# 16251   tt1921078          Saint Petersburg            San Peterzburg  2010
#
# ...

# %%
df.loc[(df['year'] < 2000) | (df['average_rating'] < 8.0), ['title', 'year', 'average_rating']]
# Out:
#                           title  year  average_rating
# 0      The Shawshank Redemption  1994             9.3
# 3                    Fight Club  1999             8.8
# 5                  Forrest Gump  1994             8.8
# 6                  Pulp Fiction  1994             8.8
# 7                    The Matrix  1999             8.7
# ...                         ...   ...             ...
# 16247                   Belgica  2016             6.7
# 16248    Dil Hai Ki Manta Nahin  1991             7.2
# 16249                 The Binge  2020             5.3
# 16250               Billionaire  1987             7.5
# 16251          Saint Petersburg  2010             6.4
#
# [15708 rows x 3 columns]

# %%
df
